# %%
# Imports
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.ensemble import GradientBoostingClassifier
from skimage.feature import greycomatrix, greycoprops
from sklearn import metrics

# %%
from ipynb.fs.full.FindFractalFeatures import x_train, y_train, x_test, y_test
# Out:
#  length of training set is 272
#  length of validation set is 91
# (272,) (272,)
# (272, 12) (272,)

# %% [markdown]
# ## Gradient Boosting - Training

# %%
# Boost 100 weak decision trees
x_train, x_test = x_train_filtered, x_test_filtered
model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1)

model = model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/essam/Documents/GitHub/Gender-Classification-ICDAR2013/GradientBoost.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/Gender-Classification-ICDAR2013/GradientBoost.ipynb#ch0000003?line=0'>1</a> # Boost 100 weak decision trees
# ----> <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/Gender-Classification-ICDAR2013/GradientBoost.ipynb#ch0000003?line=1'>2</a> x_train, x_test = x_train_filtered, x_test_filtered
#       <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/Gender-Classification-ICDAR2013/GradientBoost.ipynb#ch0000003?line=2'>3</a> model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1)
#       <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/Gender-Classification-ICDAR2013/GradientBoost.ipynb#ch0000003?line=4'>5</a> model = model.fit(x_train, y_train)
#
# NameError: name 'x_train_filtered' is not defined

# %% [markdown]
# ## Gradient Boosted Trees - Testing

# %%
predictions = model.predict(x_test)
print(metrics.accuracy_score(y_test, predictions) * 100)
# Out:
# 63.73626373626373
