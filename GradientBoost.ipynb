# %%
# Imports
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.ensemble import GradientBoostingClassifier
from skimage.feature import greycomatrix, greycoprops
from sklearn import metrics

# %%
# %run FindFractalFeatures.ipynb
# Out:
#   0%|          | 0/272 [00:00<?, ?it/s]
#  length of training set is 272
#  length of validation set is 91
# C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_17660/2379999910.py:6: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   hist,bins = np.histogram(img.ravel(),256,[0,256],True)
# 100%|██████████| 272/272 [11:14<00:00,  2.48s/it]
# 100%|██████████| 91/91 [03:25<00:00,  2.26s/it]

# %% [markdown]
# ## Gradient Boosting - Training

# %%
# Boost 100 weak decision trees
#x_train, x_test = x_train_filtered, x_test_filtered
model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1)

model = model.fit(x_train, y_train)

# %% [markdown]
# ## Gradient Boosted Trees - Testing

# %%
predictions = model.predict(x_test)
print(metrics.accuracy_score(y_test, predictions) * 100)
# Out:
# 58.24175824175825
